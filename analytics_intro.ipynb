# %%
print("My name is Nidhi")
print("My favourite app is Instagram")
# Out:
# My name is Nidhi
# My favourite app is Instagram

# %%
import datetime

print(datetime.datetime.now().year)
# Out:
# 2026

# %%
product="Redmi Note 12 Pro"
print(product.upper())
print(product.lower())
# Out:
# REDMI NOTE 12 PRO
# redmi note 12 pro

# %%
def clean_brand_name(name):
    name=name.strip()
    name=name.replace("-"," ")
    return name 
product = "oneplus-Nord"
print(clean_brand_name(product))
# Out:
# oneplus Nord

# %%
product="Apple iPhone 14 Pro Max"
parts=product.split(" ",1)
brand=parts[0]
model=parts[1]
print(brand)
print(model)
# Out:
# Apple
# iPhone 14 Pro Max

# %%
def format_product_display(name,price):
    return f" {name} - {price}"
name="Boat Earbuds"
price=1299
print(format_product_display(name,price))
# Out:
#  Boat Earbuds - 1299

# %%
products=[' mi-Band 5 ', ' SAMSUNG-Galaxy ', ' realme-Book']
clean_products=[]
for product in products:
    product=product.strip()
    product=product.replace("-"," ")
    product=product.title()
    clean_products.append(product)
print(clean_products)
# Out:
# ['Mi Band 5', 'Samsung Galaxy', 'Realme Book']

# %%
followers=1200
rating=4.5
app_name="whatsapp"
is_premium_user= True

print(followers,type(followers))
print(rating,type(rating))
print(app_name,type(app_name))
print(is_premium_user,type(is_premium_user))
# Out:
# 1200 <class 'int'>
# 4.5 <class 'float'>
# whatsapp <class 'str'>
# True <class 'bool'>

# %%
price=input("Enter Zomato order price:")
price=float(price)
gst=price*0.18
final_bill=price+gst
print("Final Bill amount is :",final_bill)
# Out:
# Final Bill amount is : 590.0

# %%
prices=['199.99', '299.50', '150']
prices_float=[float(price) for price in prices]
total=sum(prices_float)
print("Total of your cart is :",total)
# Out:
# Total of your cart is : 649.49

# %%
def  is_discount_applicable(order_amount):
    if order_amount>500:
        return True
    else:
        return False
print(is_discount_applicable(450))
print(is_discount_applicable(750))
# Out:
# False
# True

# %%
ratings=['4.5', '3.0', '5', '4.2']
ratings_float=[float(rating) for rating in ratings ]
highest_rating=max(ratings_float)
print("Highest Rating :", highest_rating)
# Out:
# Highest Rating : 5.0

# %%
user_name="Nidhi Prajapati"
fav_app = "Youtube"
daily_usage_hours = 4 
print(user_name)
print(fav_app)
print(daily_usage_hours)
# Out:
# Nidhi Prajapati
# Youtube
# 4

# %%
product_name= "i phone"
price= 59999.0
is_available =True
print(product_name,type(product_name))
print(price, type(price))
print(is_available,type(is_available))
# Out:
# i phone <class 'str'>
# 59999.0 <class 'float'>
# True <class 'bool'>

# %%
# This is a Spotify playlist recommendation system

playlist_name = "My Favorites"
user_mood = "Happy"

"""
The recommendation system can check
the user's mood and playlist history
to recommend suitable songs.
"""

print("Playlist:", playlist_name)
print("Mood:", user_mood)
# Out:
# Playlist: My Favorites
# Mood: Happy

# %%
order_total=1000
delivery_region="Ahmedabad"
discount_percent=10
print("Order from", delivery_region ,"totals ₹", order_total, "with ", discount_percent ,"% discount")
# Out:
# Order from Ahmedabad totals ₹ 1000 with  10 % discount

# %%
if True:
    print("This is correctly indented")
    print("Python uses spaces for indentation")

print("Program completed successfully")
# Out:
# This is correctly indented
# Python uses spaces for indentation
# Program completed successfully

# %%
playlist_ids=[101,102,103,104,105]
playlist_ids.append(106)
print(playlist_ids)
# Out:
# [101, 102, 103, 104, 105, 106]

# %%
Flipkart_items=["t-shirt", "shoes"]
Flipkart_items.extend(["jeans","cap"])
print(Flipkart_items)
# Out:
# ['t-shirt', 'shoes', 'jeans', 'cap']

# %%
def remove_last_item(order_list):
    removed_item=order_list.pop()
    return removed_item
order=["pizza","burger","fries","noodles"]
remove=remove_last_item(order)
print("removed item ="  ,remove)
print("updated orders list is =",order)
# Out:
# removed item = noodles
# updated orders list is = ['pizza', 'burger', 'fries']

# %%
insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")

# This gives an error because tuples are immutable.
# We cannot directly change an existing element of a tuple.

insta_filters[1] = "Paris"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 # This gives an error because tuples are immutable.
#       4 # We cannot directly change an existing element of a tuple.
#       5
# ----> 6 insta_filters[1] = "Paris"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#user favourite genre may change. so we will use list as they are mutable .
fav_genres=["hip-hop","pop","rock"]

#IRCTC train classes are fixed. so we will use tuple as they cannot be changed.
IRCTC_classess=('Sleeper', 'AC 3 Tier', 'AC 2 Tier')
print("favourite genre :",fav_genres)
print("IRCTC classess :",IRCTC_classess)
# Out:
# favourite genre : ['hip-hop', 'pop', 'rock']
# IRCTC classess : ('Sleeper', 'AC 3 Tier', 'AC 2 Tier')

# %%
playlist_prices = {
    "Workout Mix": 199,
    "Chill Vibes": 149,
    "Party Hits": 249,
    "Road Trip": 299,
    "Focus Music": 179
}

print(playlist_prices)
# Out:
# {'Workout Mix': 199, 'Chill Vibes': 149, 'Party Hits': 249, 'Road Trip': 299, 'Focus Music': 179}

# %%
def update_playlist_price(playlist, new_price):
    playlist_prices[playlist]=new_price
update_playlist_price("Chill Vibes", 199)

print(playlist_prices)
# Out:
# {'Workout Mix': 199, 'Chill Vibes': 199, 'Party Hits': 249, 'Road Trip': 299, 'Focus Music': 179}

# %%
del playlist_prices["Road Trip"]
print(playlist_prices)
# Out:
# {'Workout Mix': 199, 'Chill Vibes': 199, 'Party Hits': 249, 'Focus Music': 179}

# %%
zomato_restaurents={"burger king","KFC","jai bhavani","mcdonals"}
swiggy_restaurents={"pizza hut","la pino'z pizza","KFC",}
print("Union:", zomato_restaurents.union(swiggy_restaurents))
print("Intersection:", zomato_restaurents.intersection(swiggy_restaurents))
# Out:
# Union: {"la pino'z pizza", 'KFC', 'burger king', 'mcdonals', 'jai bhavani', 'pizza hut'}
# Intersection: {'KFC'}

# %%
age=int(input("enter your age :"))
if age>=18:
    print("Eligible for IPL ticket booking")
else:
    print("not eligible")
# Out:
# Eligible for IPL ticket booking

# %%
followers=int(input("enter number of followers :"))
if followers<10000:
    print("Micro Influencer")
elif followers >=10000 and followers<=100000:
    print("rising stars")
else:
    print("celebrity")
# Out:
# celebrity

# %%
total=int(input("enter Zomato total :"))
if total>299:
    print("free delivery")
elif total>=200 and total<299 :
    print("add more items to get free delivery")
else:
    print("delivery charges applied")
# Out:
# add more items to get free delivery

# %%
total=int(input("enter flipkart value :"))
payment=input("enter payment method (UPI/card/cash):")
if total>1000:
    if payment =="UPI":
        print("eligible for 10%")
    else:
        print("eligible for 5%")

else:
    print("no cashback")
# Out:
# eligible for 10%

# %%
order_amounts=[120, 250, 90, 310, 150]
total=0
for amount in order_amounts:
    total+=amount
print("total :",total)
# Out:
# total : 920

# %%
scores = [45, 78, 102, 34, 67, 89]

i = 0

while i < len(scores):
    if scores[i] > 100:
        break
    print(scores[i])
    i += 1
# Out:
# 45
# 78

# %%
item_prices = [299, 499, 199, 999, 149]

total = 0

for price in item_prices:
    if price < 200:
        continue
    print(price)
    total += price

print("Total:", total)
# Out:
# 299
# 499
# 999
# Total: 1797

# %%
songs = ["Kesariya", "Believer", "Shape of You", "Blinding Lights", "Excuses"]

for position, song in enumerate(songs, start=1):
    print(position, song)
# Out:
# 1 Kesariya
# 2 Believer
# 3 Shape of You
# 4 Blinding Lights
# 5 Excuses

# %%
followers = [120, 1500, 23000, 800, 45000]

for count in followers:
    if count < 1000:
        print(count, "Micro")
    elif count <= 10000:
        print(count, "Influencer")
    else:
        print(count, "Celebrity")
# Out:
# 120 Micro
# 1500 Influencer
# 23000 Celebrity
# 800 Micro
# 45000 Celebrity
